# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request

# %%
#os.chdir("Desktop/")

# %%
url = "https://www.f1-fansite.com/f1-results/1950-f1-championship-standings/"
r = requests.get(url)
text = r.text
soup = BeautifulSoup(text)

# %%
#print(soup.prettify())

# %%
My_table = soup.find("table", {"class":"motor-sport-results msr_season_driver_results"})
#print(My_table)

# %%
table_body = My_table.find('tbody')
#table_body

# %%
data = []
rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for  ele in cols]
    data.append([ele for ele in cols if ele])

# %%
#data

# %%
tab = pd.DataFrame(data)
#tab

# %%
table_head = My_table.find('thead')
#table_head

# %%
headers = []
rows = table_head.find_all('tr')
#rows

# %%
for row in rows:
    cols = row.find_all('th')
    cols = [ele.text.strip() for  ele in cols]
    headers.append([ele for ele in cols if ele])

# %%
nombres = np.array(headers)

# %%
headers2=headers[0][0:-1]
tab.columns = headers2
tab = tab.set_index('Pos')

# %%
tab
# Out:
#                     Driver  BRI  MON  INDY   SWI   BEL   FRE      ITA
# Pos
# 1              Nino Farina    1  Ret     1     4     7     1       30
# 2       Juan Manuel Fangio  Ret    1   Ret     1     1   Ret       27
# 3            Luigi Fagioli    2  Ret     2     2     2     3  24 (28)
# 4             Louis Rosier    5  Ret     3     3     6     4       13
# 5           Alberto Ascari    2  Ret     5   DNQ     2    11     None
# 6          Johnnie Parsons    1    9  None  None  None  None     None
# 7             Bill Holland    2    6  None  None  None  None     None
# 8              Prince Bira  Ret    5     4   Ret     5  None     None
# 9          Peter Whitehead  DNS    3     7     4  None  None     None
# 10            Louis Chiron  Ret    3     9   Ret   Ret     4     None
# 11             Reg Parnell    3  Ret     4  None  None  None     None
# 12              Mauri Rose    3    4  None  None  None  None     None
# 13         Dorino Serafini    2    3  None  None  None  None     None
# 14   Yves Giraud Cabantous    4  Ret   Ret     8     3  None     None
# 15          Raymond Sommer    4  Ret   Ret   Ret   Ret     3     None
# 16           Robert Manzon  Ret    4   Ret     3  None  None     None
# 17             Cecil Green    4    3  None  None  None  None     None
# 18      Philippe Étancelin    8  Ret   Ret   Ret     5     5        3
# 19          Felice Bonetto    5  Ret   DNS     2  None  None     None
# 20          Eugène Chaboud  Ret    5     1  None  None  None     None
# 21       Tony Bettenhausen    5    1  None  None  None  None     None
# 22           Joie Chitwood    5    1  None  None  None  None     None
# 23    Toulo de Graffenried  Ret  Ret     6     6     0  None     None
# 24              Bob Gerard    6    6     0  None  None  None     None
# 25         Luigi Villoresi  Ret  Ret     6   DNQ     0  None     None
# 26             Lee Wallard    6    0  None  None  None  None     None
# 27           Charles Pozzi    6    0  None  None  None  None     None
# 28            Johnny Claes   11    7    10     8   Ret   Ret        0
# 29           Pierre Levegh    7  Ret   Ret     0  None  None     None
# 30           Cuth Harrison    7  Ret   Ret     0  None  None     None
# ..                     ...  ...  ...   ...   ...   ...   ...      ...
# 52              Jerry Hoyt   21    0  None  None  None  None     None
# 53               Walt Ader   22    0  None  None  None  None     None
# 54           Jackie Holmes   23    0  None  None  None  None     None
# 55            Jim Rathmann   24    0  None  None  None  None     None
# 56             Henry Banks   25    0  None  None  None  None     None
# 57          Bill Schindler   26    0  None  None  None  None     None
# 58           Bill Cantrell   27    0  None  None  None  None     None
# 59         Bayliss Levrett   27    0  None  None  None  None     None
# 60         Fred Agabashian   28    0  None  None  None  None     None
# 61           Jimmy Jackson   29    0  None  None  None  None     None
# 62               Sam Hanks   30    0  None  None  None  None     None
# 63           Dick Rathmann   32    0  None  None  None  None     None
# 64           Duke Dinsmore   33    0  None  None  None  None     None
# 65            David Murray  Ret  Ret     0  None  None  None     None
# 66   José Froilán González  Ret  Ret     0  None  None  None     None
# 67            Guy Mairesse  Ret    0  None  None  None  None     None
# 68              Franco Rol  Ret  Ret   Ret     0  None  None     None
# 69               Joe Kelly   NC    0  None  None  None  None     None
# 70           Piero Taruffi  Ret    0  None  None  None  None     None
# 71           Eugène Martin  Ret  Ret     0  None  None  None     None
# 72     Maurice Trintignant  Ret  Ret     0  None  None  None     None
# 73      Clemente Biondetti  Ret    0  None  None  None  None     None
# 74           Henri Louveau  Ret    0  None  None  None  None     None
# 75          Franco Comotti  DNP  Ret     0  None  None  None     None
# 76               Tony Rolt  Ret    0  None  None  None  None     None
# 77            Peter Walker  Ret    0  None  None  None  None     None
# 78          Leslie Johnson  Ret    0  None  None  None  None     None
# 79            Alfredo Piàn  DNS    0  None  None  None  None     None
# 80         Consalvo Sanesi  Ret    0  None  None  None  None     None
# 81            Paul Pietsch  Ret    0  None  None  None  None     None
#
# [81 rows x 8 columns]

# %%
url="https://www.f1-fansite.com/f1-results/1950-f1-championship-standings/"

# %%
URLs=np.repeat(url,2019-1950+1, axis=0)

# %%
years=list(range(1950, 2020))

# %%
for x in range(0,2019-1950+1):
        URLs[x] = URLs[x].replace("1950", str(years)[1+x*6:5+x*6])
