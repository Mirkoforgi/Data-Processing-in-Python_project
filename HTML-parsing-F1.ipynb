# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request

# %%
#os.chdir("Desktop/")

# %%
url = "https://www.f1-fansite.com/f1-results/1950-f1-championship-standings/"
r = requests.get(url)
text = r.text
soup = BeautifulSoup(text)

# %%
#print(soup.prettify())

# %%
My_table = soup.find("table", {"class":"motor-sport-results msr_season_driver_results"})
#print(My_table)

# %%
table_body = My_table.find('tbody')
#table_body

# %%
data = []
rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for  ele in cols]
    data.append([ele for ele in cols if ele])

# %%
data
# Out:
# [['1', 'Nino Farina', '1', 'Ret', '1', '4', '7', '1', '30'],
#  ['2', 'Juan Manuel Fangio', 'Ret', '1', 'Ret', '1', '1', 'Ret', '27'],
#  ['3', 'Luigi Fagioli', '2', 'Ret', '2', '2', '2', '3', '24 (28)'],
#  ['4', 'Louis Rosier', '5', 'Ret', '3', '3', '6', '4', '13'],
#  ['5', 'Alberto Ascari', '2', 'Ret', '5', 'DNQ', '2', '11'],
#  ['6', 'Johnnie Parsons', '1', '9'],
#  ['7', 'Bill Holland', '2', '6'],
#  ['8', 'Prince Bira', 'Ret', '5', '4', 'Ret', '5'],
#  ['9', 'Peter Whitehead', 'DNS', '3', '7', '4'],
#  ['10', 'Louis Chiron', 'Ret', '3', '9', 'Ret', 'Ret', '4'],
#  ['11', 'Reg Parnell', '3', 'Ret', '4'],
#  ['12', 'Mauri Rose', '3', '4'],
#  ['13', 'Dorino Serafini', '2', '3'],
#  ['14', 'Yves Giraud Cabantous', '4', 'Ret', 'Ret', '8', '3'],
#  ['15', 'Raymond Sommer', '4', 'Ret', 'Ret', 'Ret', 'Ret', '3'],
#  ['16', 'Robert Manzon', 'Ret', '4', 'Ret', '3'],
#  ['17', 'Cecil Green', '4', '3'],
#  ['18', 'Philippe Étancelin', '8', 'Ret', 'Ret', 'Ret', '5', '5', '3'],
#  ['19', 'Felice Bonetto', '5', 'Ret', 'DNS', '2'],
#  ['20', 'Eugène Chaboud', 'Ret', '5', '1'],
#  ['21', 'Tony Bettenhausen', '5', '1'],
#  ['22', 'Joie Chitwood', '5', '1'],
#  ['23', 'Toulo de Graffenried', 'Ret', 'Ret', '6', '6', '0'],
#  ['24', 'Bob Gerard', '6', '6', '0'],
#  ['25', 'Luigi Villoresi', 'Ret', 'Ret', '6', 'DNQ', '0'],
#  ['26', 'Lee Wallard', '6', '0'],
#  ['27', 'Charles Pozzi', '6', '0'],
#  ['28', 'Johnny Claes', '11', '7', '10', '8', 'Ret', 'Ret', '0'],
#  ['29', 'Pierre Levegh', '7', 'Ret', 'Ret', '0'],
#  ['30', 'Cuth Harrison', '7', 'Ret', 'Ret', '0'],
#  ['31', 'Walt Faulkner', '7', '0'],
#  ['32', 'Nello Pagani', '7', '0'],
#  ['33', 'Harry Schell', 'Ret', '8', '0'],
#  ['34', 'George Connor', '8', '0'],
#  ['35', 'Geoff Crossley', 'Ret', '9', '0'],
#  ['36', 'David Hampshire', '9', 'Ret', '0'],
#  ['37', 'Paul Russo', '9', '0'],
#  ['38', 'Toni Branca', '11', '10', '0'],
#  ['39', 'Joe Fry', '10', '0'],
#  ['40', 'Brian Shawe Taylor', '10', '0'],
#  ['41', 'Pat Flaherty', '10', '0'],
#  ['42', 'Myron Fohr', '11', '0'],
#  ['43', 'Duane Carter', '12', '0'],
#  ['44', 'Mack Hellings', '13', '0'],
#  ['45', 'Jack McGrath', '14', '0'],
#  ['46', 'Troy Ruttman', '15', '0'],
#  ['47', 'Gene Hartley', '16', '0'],
#  ['48', 'Jimmy Davies', '17', '0'],
#  ['49', 'Johnny McDowell', '18', '0'],
#  ['50', 'Walt Brown', '19', '0'],
#  ['51', 'Spider Webb', '20', '0'],
#  ['52', 'Jerry Hoyt', '21', '0'],
#  ['53', 'Walt Ader', '22', '0'],
#  ['54', 'Jackie Holmes', '23', '0'],
#  ['55', 'Jim Rathmann', '24', '0'],
#  ['56', 'Henry Banks', '25', '0'],
#  ['57', 'Bill Schindler', '26', '0'],
#  ['58', 'Bill Cantrell', '27', '0'],
#  ['59', 'Bayliss Levrett', '27', '0'],
#  ['60', 'Fred Agabashian', '28', '0'],
#  ['61', 'Jimmy Jackson', '29', '0'],
#  ['62', 'Sam Hanks', '30', '0'],
#  ['63', 'Dick Rathmann', '32', '0'],
#  ['64', 'Duke Dinsmore', '33', '0'],
#  ['65', 'David Murray', 'Ret', 'Ret', '0'],
#  ['66', 'José Froilán González', 'Ret', 'Ret', '0'],
#  ['67', 'Guy Mairesse', 'Ret', '0'],
#  ['68', 'Franco Rol', 'Ret', 'Ret', 'Ret', '0'],
#  ['69', 'Joe Kelly', 'NC', '0'],
#  ['70', 'Piero Taruffi', 'Ret', '0'],
#  ['71', 'Eugène Martin', 'Ret', 'Ret', '0'],
#  ['72', 'Maurice Trintignant', 'Ret', 'Ret', '0'],
#  ['73', 'Clemente Biondetti', 'Ret', '0'],
#  ['74', 'Henri Louveau', 'Ret', '0'],
#  ['75', 'Franco Comotti', 'DNP', 'Ret', '0'],
#  ['76', 'Tony Rolt', 'Ret', '0'],
#  ['77', 'Peter Walker', 'Ret', '0'],
#  ['78', 'Leslie Johnson', 'Ret', '0'],
#  ['79', 'Alfredo Piàn', 'DNS', '0'],
#  ['80', 'Consalvo Sanesi', 'Ret', '0'],
#  ['81', 'Paul Pietsch', 'Ret', '0']]

# %%
tab = pd.DataFrame(data)
tab
# Out:
#      0                      1    2    3     4     5     6     7        8
# 0    1            Nino Farina    1  Ret     1     4     7     1       30
# 1    2     Juan Manuel Fangio  Ret    1   Ret     1     1   Ret       27
# 2    3          Luigi Fagioli    2  Ret     2     2     2     3  24 (28)
# 3    4           Louis Rosier    5  Ret     3     3     6     4       13
# 4    5         Alberto Ascari    2  Ret     5   DNQ     2    11     None
# 5    6        Johnnie Parsons    1    9  None  None  None  None     None
# 6    7           Bill Holland    2    6  None  None  None  None     None
# 7    8            Prince Bira  Ret    5     4   Ret     5  None     None
# 8    9        Peter Whitehead  DNS    3     7     4  None  None     None
# 9   10           Louis Chiron  Ret    3     9   Ret   Ret     4     None
# 10  11            Reg Parnell    3  Ret     4  None  None  None     None
# 11  12             Mauri Rose    3    4  None  None  None  None     None
# 12  13        Dorino Serafini    2    3  None  None  None  None     None
# 13  14  Yves Giraud Cabantous    4  Ret   Ret     8     3  None     None
# 14  15         Raymond Sommer    4  Ret   Ret   Ret   Ret     3     None
# 15  16          Robert Manzon  Ret    4   Ret     3  None  None     None
# 16  17            Cecil Green    4    3  None  None  None  None     None
# 17  18     Philippe Étancelin    8  Ret   Ret   Ret     5     5        3
# 18  19         Felice Bonetto    5  Ret   DNS     2  None  None     None
# 19  20         Eugène Chaboud  Ret    5     1  None  None  None     None
# 20  21      Tony Bettenhausen    5    1  None  None  None  None     None
# 21  22          Joie Chitwood    5    1  None  None  None  None     None
# 22  23   Toulo de Graffenried  Ret  Ret     6     6     0  None     None
# 23  24             Bob Gerard    6    6     0  None  None  None     None
# 24  25        Luigi Villoresi  Ret  Ret     6   DNQ     0  None     None
# 25  26            Lee Wallard    6    0  None  None  None  None     None
# 26  27          Charles Pozzi    6    0  None  None  None  None     None
# 27  28           Johnny Claes   11    7    10     8   Ret   Ret        0
# 28  29          Pierre Levegh    7  Ret   Ret     0  None  None     None
# 29  30          Cuth Harrison    7  Ret   Ret     0  None  None     None
# ..  ..                    ...  ...  ...   ...   ...   ...   ...      ...
# 51  52             Jerry Hoyt   21    0  None  None  None  None     None
# 52  53              Walt Ader   22    0  None  None  None  None     None
# 53  54          Jackie Holmes   23    0  None  None  None  None     None
# 54  55           Jim Rathmann   24    0  None  None  None  None     None
# 55  56            Henry Banks   25    0  None  None  None  None     None
# 56  57         Bill Schindler   26    0  None  None  None  None     None
# 57  58          Bill Cantrell   27    0  None  None  None  None     None
# 58  59        Bayliss Levrett   27    0  None  None  None  None     None
# 59  60        Fred Agabashian   28    0  None  None  None  None     None
# 60  61          Jimmy Jackson   29    0  None  None  None  None     None
# 61  62              Sam Hanks   30    0  None  None  None  None     None
# 62  63          Dick Rathmann   32    0  None  None  None  None     None
# 63  64          Duke Dinsmore   33    0  None  None  None  None     None
# 64  65           David Murray  Ret  Ret     0  None  None  None     None
# 65  66  José Froilán González  Ret  Ret     0  None  None  None     None
# 66  67           Guy Mairesse  Ret    0  None  None  None  None     None
# 67  68             Franco Rol  Ret  Ret   Ret     0  None  None     None
# 68  69              Joe Kelly   NC    0  None  None  None  None     None
# 69  70          Piero Taruffi  Ret    0  None  None  None  None     None
# 70  71          Eugène Martin  Ret  Ret     0  None  None  None     None
# 71  72    Maurice Trintignant  Ret  Ret     0  None  None  None     None
# 72  73     Clemente Biondetti  Ret    0  None  None  None  None     None
# 73  74          Henri Louveau  Ret    0  None  None  None  None     None
# 74  75         Franco Comotti  DNP  Ret     0  None  None  None     None
# 75  76              Tony Rolt  Ret    0  None  None  None  None     None
# 76  77           Peter Walker  Ret    0  None  None  None  None     None
# 77  78         Leslie Johnson  Ret    0  None  None  None  None     None
# 78  79           Alfredo Piàn  DNS    0  None  None  None  None     None
# 79  80        Consalvo Sanesi  Ret    0  None  None  None  None     None
# 80  81           Paul Pietsch  Ret    0  None  None  None  None     None
#
# [81 rows x 9 columns]

# %%
table_head = My_table.find('thead')
table_head
# Out:
# <thead><tr><th class="msr_pos">Pos</th><th class="msr_driver">Driver</th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-great-britain/" title="British Grand Prix">BRI</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-monaco/" title="Monaco Grand Prix">MON</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-indianapolis-500/" title="Indianapolis 500">INDY</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-switzerland/" title="Swiss Grand Prix">SWI</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-belgium/" title="Belgian Grand Prix">BEL</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-france/" title="French Grand Prix">FRE</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-italy/" title="Italian Grand Prix">ITA</a></th><th class="msr_total">Pts</th></tr></thead>

# %%
headers = []
rows = table_head.find_all('tr')
rows
# Out:
# [<tr><th class="msr_pos">Pos</th><th class="msr_driver">Driver</th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-great-britain/" title="British Grand Prix">BRI</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-monaco/" title="Monaco Grand Prix">MON</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-indianapolis-500/" title="Indianapolis 500">INDY</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-switzerland/" title="Swiss Grand Prix">SWI</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-belgium/" title="Belgian Grand Prix">BEL</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-france/" title="French Grand Prix">FRE</a></th><th><a href="https://www.f1-fansite.com/f1-result/results-1950-formula-1-grand-prix-of-italy/" title="Italian Grand Prix">ITA</a></th><th class="msr_total">Pts</th></tr>]

# %%
for row in rows:
    cols = row.find_all('th')
    cols = [ele.text.strip() for  ele in cols]
    headers.append([ele for ele in cols if ele])

# %%
nombres = np.array(headers)
nombres
# Out:
# array([['Pos', 'Driver', 'BRI', 'MON', 'INDY', 'SWI', 'BEL', 'FRE',
#         'ITA', 'Pts']], dtype='<U6')

# %%
headers2=headers[0][0:-1]
tab.columns = headers2
tab = tab.set_index('Pos')

# %%
tab
# Out:
#                     Driver  BRI  MON  INDY   SWI   BEL   FRE      ITA
# Pos
# 1              Nino Farina    1  Ret     1     4     7     1       30
# 2       Juan Manuel Fangio  Ret    1   Ret     1     1   Ret       27
# 3            Luigi Fagioli    2  Ret     2     2     2     3  24 (28)
# 4             Louis Rosier    5  Ret     3     3     6     4       13
# 5           Alberto Ascari    2  Ret     5   DNQ     2    11     None
# 6          Johnnie Parsons    1    9  None  None  None  None     None
# 7             Bill Holland    2    6  None  None  None  None     None
# 8              Prince Bira  Ret    5     4   Ret     5  None     None
# 9          Peter Whitehead  DNS    3     7     4  None  None     None
# 10            Louis Chiron  Ret    3     9   Ret   Ret     4     None
# 11             Reg Parnell    3  Ret     4  None  None  None     None
# 12              Mauri Rose    3    4  None  None  None  None     None
# 13         Dorino Serafini    2    3  None  None  None  None     None
# 14   Yves Giraud Cabantous    4  Ret   Ret     8     3  None     None
# 15          Raymond Sommer    4  Ret   Ret   Ret   Ret     3     None
# 16           Robert Manzon  Ret    4   Ret     3  None  None     None
# 17             Cecil Green    4    3  None  None  None  None     None
# 18      Philippe Étancelin    8  Ret   Ret   Ret     5     5        3
# 19          Felice Bonetto    5  Ret   DNS     2  None  None     None
# 20          Eugène Chaboud  Ret    5     1  None  None  None     None
# 21       Tony Bettenhausen    5    1  None  None  None  None     None
# 22           Joie Chitwood    5    1  None  None  None  None     None
# 23    Toulo de Graffenried  Ret  Ret     6     6     0  None     None
# 24              Bob Gerard    6    6     0  None  None  None     None
# 25         Luigi Villoresi  Ret  Ret     6   DNQ     0  None     None
# 26             Lee Wallard    6    0  None  None  None  None     None
# 27           Charles Pozzi    6    0  None  None  None  None     None
# 28            Johnny Claes   11    7    10     8   Ret   Ret        0
# 29           Pierre Levegh    7  Ret   Ret     0  None  None     None
# 30           Cuth Harrison    7  Ret   Ret     0  None  None     None
# ..                     ...  ...  ...   ...   ...   ...   ...      ...
# 52              Jerry Hoyt   21    0  None  None  None  None     None
# 53               Walt Ader   22    0  None  None  None  None     None
# 54           Jackie Holmes   23    0  None  None  None  None     None
# 55            Jim Rathmann   24    0  None  None  None  None     None
# 56             Henry Banks   25    0  None  None  None  None     None
# 57          Bill Schindler   26    0  None  None  None  None     None
# 58           Bill Cantrell   27    0  None  None  None  None     None
# 59         Bayliss Levrett   27    0  None  None  None  None     None
# 60         Fred Agabashian   28    0  None  None  None  None     None
# 61           Jimmy Jackson   29    0  None  None  None  None     None
# 62               Sam Hanks   30    0  None  None  None  None     None
# 63           Dick Rathmann   32    0  None  None  None  None     None
# 64           Duke Dinsmore   33    0  None  None  None  None     None
# 65            David Murray  Ret  Ret     0  None  None  None     None
# 66   José Froilán González  Ret  Ret     0  None  None  None     None
# 67            Guy Mairesse  Ret    0  None  None  None  None     None
# 68              Franco Rol  Ret  Ret   Ret     0  None  None     None
# 69               Joe Kelly   NC    0  None  None  None  None     None
# 70           Piero Taruffi  Ret    0  None  None  None  None     None
# 71           Eugène Martin  Ret  Ret     0  None  None  None     None
# 72     Maurice Trintignant  Ret  Ret     0  None  None  None     None
# 73      Clemente Biondetti  Ret    0  None  None  None  None     None
# 74           Henri Louveau  Ret    0  None  None  None  None     None
# 75          Franco Comotti  DNP  Ret     0  None  None  None     None
# 76               Tony Rolt  Ret    0  None  None  None  None     None
# 77            Peter Walker  Ret    0  None  None  None  None     None
# 78          Leslie Johnson  Ret    0  None  None  None  None     None
# 79            Alfredo Piàn  DNS    0  None  None  None  None     None
# 80         Consalvo Sanesi  Ret    0  None  None  None  None     None
# 81            Paul Pietsch  Ret    0  None  None  None  None     None
#
# [81 rows x 8 columns]

# %%
url="https://www.f1-fansite.com/f1-results/1950-f1-championship-standings/"

# %%
URLs=np.repeat(url,2019-1950+1, axis=0)

# %%
years=list(range(1950, 2020))

# %%
for x in range(0,2019-1950+1):
        URLs[x] = URLs[x].replace("1950", str(years)[1+x*6:5+x*6])
